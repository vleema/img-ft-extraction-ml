# %% [markdown]
# # Análise de características usando $k$-$NN$
#
# ### TODO
#
# - [ ] Exibir imagens das raças sendo análisadas para introdução.
# - [ ] Escolher e justificar escolha das 12 bases.
# - [ ] Separar dados de teste usando holdout e $k$-fold.
#     - [ ] Definir $k$ no $k$-fold e quantos holdouts serão utilizados.
# - [ ] Calcular F1-score, desvio padrão e média para diferentes valores de $k$ ($k$-$NN$), variando de 1 até 10.

# %%
print("Hello World!")
# Out:
# Hello World!
